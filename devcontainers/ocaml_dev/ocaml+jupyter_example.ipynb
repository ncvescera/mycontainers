# %% [markdown]
# # Ocaml + Jupyter Example

# %% [markdown]
# You can run noraml Ocaml operations:

# %%
let a = 2;;
# Out:
# val a : int = 2

# %%
a
# Out:
# - : int = 2

# %% [markdown]
# If you need some advanced stuff like: displaing HTML, Images, running bash commands, you can do this:

# %%
#require "jupyter.notebook" ;;
open Jupyter_notebook ;;

# %%
Jupyter_notebook.display "text/html" "<b>Hello, World!</b>"
# Out:
# <b>Hello, World!</b>
# - : Jupyter_notebook.display_id = <abstr>

# %%
Process.sh "ls"
# Out:
# test.ipynb
# test.ml
# - : Jupyter_notebook.Process.t =
# {Jupyter_notebook.Process.exit_status = Unix.WEXITED 0; stdout = None;
#  stderr = None}

# %% [markdown]
# **Note:** `!ls` or similar commands does not work, you have to use `Process.sh "ls"`!!!

# %% [markdown]
# You can copy images from the internet/local memory as a normal notebook

# %% [markdown]
# ![giphy.webp](attachment:giphy.webp)
